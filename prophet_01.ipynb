# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.1.4-py3-none-win_amd64.whl (12.9 MB)
#                                               0.0/12.9 MB ? eta -:--:--
#      -                                        0.5/12.9 MB 16.8 MB/s eta 0:00:01
#      ----                                     1.5/12.9 MB 18.6 MB/s eta 0:00:01
#      --------                                 2.8/12.9 MB 22.0 MB/s eta 0:00:01
#      -------------                            4.2/12.9 MB 24.3 MB/s eta 0:00:01
#      -------------                            4.2/12.9 MB 24.3 MB/s eta 0:00:01
#      -------------                            4.2/12.9 MB 24.3 MB/s eta 0:00:01
#      -------------                            4.5/12.9 MB 14.4 MB/s eta 0:00:01
#      ---------------------                    7.0/12.9 MB 19.6 MB/s eta 0:00:01
#      -------------------------------         10.3/12.9 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------  12.9/12.9 MB 32.8 MB/s eta 0:00:01
#      --------------------------------------- 12.9/12.9 MB 28.5 MB/s eta 0:00:00
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
#                                               0.0/83.2 kB ? eta -:--:--
#      ---------------------------------------- 83.2/83.2 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prophet) (1.24.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prophet) (2.0.1)
# Collecting LunarCalendar>=0.0.9 (from prophet)
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2 (from prophet)
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#                                               0.0/47.9 kB ? eta -:--:--
#      ---------------------------------------- 47.9/47.9 kB 2.4 MB/s eta 0:00:00
# Collecting holidays>=0.25 (from prophet)
#   Downloading holidays-0.29-py3-none-any.whl (695 kB)
#                                               0.0/695.7 kB ? eta -:--:--
#      ------------------------------------- 695.7/695.7 kB 42.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prophet) (2.8.2)
# Collecting tqdm>=4.36.1 (from prophet)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#                                               0.0/77.1 kB ? eta -:--:--
#      ---------------------------------------- 77.1/77.1 kB ? eta 0:00:00
# Collecting importlib-resources (from prophet)
#   Using cached importlib_resources-6.0.0-py3-none-any.whl (31 kB)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.1.2->prophet)
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#                                               0.0/5.8 MB ? eta -:--:--
#      -----------------                        2.6/5.8 MB 54.3 MB/s eta 0:00:01
#      ---------------------------------        4.8/5.8 MB 51.0 MB/s eta 0:00:01
#      ---------------------------------------- 5.8/5.8 MB 45.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->prophet)
#   Downloading ephem-4.1.4-cp311-cp311-win_amd64.whl (1.4 MB)
#                                               0.0/1.4 MB ? eta -:--:--
#      -----------------------------            1.0/1.4 MB 64.6 MB/s eta 0:00:01
#      -----------------------------            1.0/1.4 MB 64.6 MB/s eta 0:00:01
#      -----------------------------            1.0/1.4 MB 64.6 MB/s eta 0:00:01
#      ---------------------------------------  1.4/1.4 MB 8.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from LunarCalendar>=0.0.9->prophet) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=2.0.0->prophet) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=2.0.0->prophet) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=2.0.0->prophet) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\nsw00_009821\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Building wheels for collected packages: pymeeus
#   Building wheel for pymeeus (pyproject.toml): started
#   Building wheel for pymeeus (pyproject.toml): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732055 sha256=469efd5178f6872a11ae8db39e4db5879468aa8e76be04062568aea1780c1d7f
#   Stored in directory: c:\users\nsw00_009821\appdata\local\pip\cache\wheels\8f\bd\f9\5c4c39b529e0322b08979e1c465e203218bc2cca75d20f7df5
# Successfully built pymeeus
# Installing collected packages: pymeeus, ephem, tqdm, importlib-resources, convertdate, LunarCalendar, holidays, cmdstanpy, prophet
# Successfully installed LunarCalendar-0.0.9 cmdstanpy-1.1.0 convertdate-2.4.0 ephem-4.1.4 holidays-0.29 importlib-resources-6.0.0 prophet-1.1.4 pymeeus-0.5.12 tqdm-4.65.0
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\NSW00_009821\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from prophet import Prophet
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#               ds          y
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374

# %%
p = Prophet()
p.fit(df)
# Out:
# 08:49:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:13 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = p.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = p.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.206605    7.561406    8.953712
# 3266 2017-01-16  8.531590    7.823478    9.283972
# 3267 2017-01-17  8.318985    7.589781    9.048283
# 3268 2017-01-18  8.151637    7.419929    8.865639
# 3269 2017-01-19  8.163528    7.486800    8.893001

# %%
fig1 = p.plot(forecast)

# %%
fig2 = p.plot_components(forecast)
